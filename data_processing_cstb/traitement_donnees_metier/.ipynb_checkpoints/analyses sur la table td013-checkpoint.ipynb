# %% [markdown]
# # import

# %%
import pandas as pd
import json
import requests
from pathlib import Path
import numpy as np
import sys
import requests
import json
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_context('talk')
# %matplotlib inline

# %% [markdown]
# # directories

# %%
if sys.platform =='linux':
    path_d = Path('/mnt/d')
else:
    path_d = Path('D://')
data_dir = path_d/'data'/'dpe_full'   

plot_dir = Path('.')/'plot'
plot_dir.mkdir(exist_ok=True,parents=True)

# %% [markdown]
# # read exemple

# %%
dept = '38'
td011 =pd.read_csv(data_dir/'depts'/dept/'td011_installation_chauffage.csv',dtype=str)
td012 =pd.read_csv(data_dir/'depts'/dept/'td012_generateur_chauffage.csv',dtype=str)
td013 =pd.read_csv(data_dir/'depts'/dept/'td013_installation_ecs.csv',dtype=str)
td014 =pd.read_csv(data_dir/'depts'/dept/'td014_generateur_ecs.csv',dtype=str)
td006 =pd.read_csv(data_dir/'depts'/dept/'td006_batiment.csv',dtype=str)
td001 =pd.read_csv(data_dir/'depts'/dept/'td001_dpe.csv',dtype=str)
td005 =pd.read_csv(data_dir/'depts'/dept/'td005_fiche_technique.csv',dtype=str)

# %%
import pandas as pd
import numpy as np
from assets_orm import DPEMetaData
from td001_merge import merge_td001_dpe_id_system

td013_types = {'td013_installation_ecs_id': 'str',
 'td006_batiment_id': 'str',
 'tr005_type_installation_ecs_id': 'str',
 'nombre_appartements_echantillon': 'float',
 'surface_habitable_echantillon': 'float',
 'becs': 'float',
 'tv039_formule_becs_id': 'category',
 'surface_alimentee': 'float',
 'td001_dpe_id': 'str'}


td014_types = {'td014_generateur_ecs_id': 'str',
 'td013_installation_ecs_id': 'str',
 'tr004_type_energie_id': 'str',
 'tv045_conversion_kwh_co2_id': 'category',
 'tv046_evaluation_contenu_co2_reseaux_id': 'category',
 'coefficient_performance': 'float',
 'tv032_coefficient_performance_id': 'category',
 'rpn': 'float',
 'qp0': 'float',
 'puissance_veilleuse': 'float',
 'tv036_puissance_veilleuse_id': 'category',
 'tv037_puissance_necessaire_production_ecs_id': 'category',
 'puissance_nominale': 'float',
 'tv038_puissance_nominale_id': 'category',
 'tv040_rendement_distribution_ecs_id': 'category',
 'tv047_rendement_generation_ecs_id': 'category',
 'volume_stockage': 'float',
 'tv048_rendement_stockage_ecs_id': 'category',
 'tv049_perte_stockage_ecs_id': 'category',
 'tv041_coefficient_emplacement_fonctionnement_id': 'category',
 'tv043_pertes_stockage_id': 'category',
 'tv019_fecs_id': 'category',
 'tv027_pertes_recuperees_ecs_id': 'category',
 'td001_dpe_id': 'str'}

def merge_td013_tr_tv(td013):
    meta = DPEMetaData()
    table = td013.copy()
    table = meta.merge_all_tr_table(table)
    table = meta.merge_all_tv_table(table)
    table = table.astype(td013_types)
    table = table.rename(columns={'id': 'td013_installation_ecs_id'})

    return table

def merge_td014_tr_tv(td014):
    meta = DPEMetaData()
    table = td014.copy()
    table = meta.merge_all_tr_table(table)
    table = meta.merge_all_tv_table(table)
    table = table.astype(td014_types)
    table = table.rename(columns={'id': 'td013_installation_ecs_id'})

    return table

td001,td006,td011, td012,td013,td014 = merge_td001_dpe_id_system(td001, td006, td011, td012,td013,td014)

td013 = merge_td013_tr_tv(td013)

td014 = merge_td014_tr_tv(td014)

# %%
from utils import strip_accents,affect_lib_by_matching_score

# %%
td005_ecs=td005.loc[td005.tr011_sous_categorie_fiche_technique_id=='17']
vr_ecs = td005_ecs.valeur_renseignee.str.lower().apply(lambda x:strip_accents(x))

# %%
mixte = ('mixte', 'combine', 'chauffage + ecs','chauffage et ecs','lie ','combine ')
gen_ecs_normalized_lib_matching_dict_ft = {
    "ballon thermodynamique electrique": [('thermodynamique', 'air extrait', 'air exterieur'),
                                          ('thermodynamique', 'air extrait', 'air exterieur'),

                                          ],
    "pompe a chaleur combinee ecs/chauffage (indeterminee)": [
        ('pac', 'pompe a chaleur'),
        mixte
    ],
    "pompe a chaleur combinee ecs/chauffage (pac air/eau)": [
        ('pac', 'pompe a chaleur'),
        mixte, 'air/eau'
    ],
    "pompe a chaleur combinee ecs/chauffage (pac geothermique)": [
        ('pac', 'pompe a chaleur'),
        mixte, 'geothermique'
    ],

    "pompe a chaleur combinee ecs/chauffage (pac air/air)": [
        ('pac', 'pompe a chaleur'),
        ('mixte', 'combine'), ('air/air', 'split')
    ],
    "pompe a chaleur combinee ecs/chauffage (pac eau/eau)": [
        ('pac', 'pompe a chaleur'),
        ('mixte', 'combine'), 'eau/eau'
    ],
    "ballon electrique": [('electricite', 'electrique','elec')],
    "ecs instantanee electrique": [('instantanee', 'instantane'), ('electricite', 'electrique')],

    'chaudiere mixte gaz': ["chaudiere", mixte, ("gaz", "gpl")],
    'chaudiere mixte fioul': ["chaudiere", mixte, "fioul"],
    'chaudiere mixte bois': ["chaudiere", mixte, "classe",
                             ("bois", "biomasse")],

    'chaudiere mixte indeterminee': ["chaudiere", mixte],
    'production mixte indeterminee': [ mixte],
    'chauffe-eau gaz independant': [("ballon", "chauffe-eau", "accumulateur", "chauffe bain"), "gaz"],
    'chauffe-eau gpl independant': [("ballon", "chauffe-eau", "accumulateur", "chauffe bain"), "gpl", 'gpl'],

    'chauffe-eau fioul independant': [("ballon", "chauffe-eau", "accumulateur", "bain"), "fioul", 'fioul'],
    "ecs collective reseau de chaleur": ["reseau de chaleur"],

    'chaudiere gaz': ["chaudiere", "gaz"],
    'chaudiere gpl': ["chaudiere", "gpl", 'gpl'],
    'chaudiere fioul': ["chaudiere", "fioul", 'fioul'],
    'chaudiere indeterminee': ["chaudiere"],

}

# %%
libs=vr_ecs.apply(lambda x:affect_lib_by_matching_score(x,gen_ecs_normalized_lib_matching_dict_ft))

# %%
test=libs=='pompe a chaleur combinee ecs/chauffage (indeterminee)'
test=libs=='pompe a chaleur combinee ecs/chauffage (pac air/air)'
test=libs=='ballon electrique'
test=libs=='chaudiere mixte gaz'
test=libs=='non affecte'
test=libs=='ecs collective reseau de chaleur'
test=libs=='chaudiere gaz'
test=libs=='ballon thermodynamique electrique'
test=libs=='chaudiere fioul'
test=libs=='chauffe-eau fioul independant'

#test=libs=='ecs collective reseau de chaleur'
#test=libs=='ecs collective reseau de chaleur'
#test=libs=='ecs collective reseau de chaleur'

# %%
test=libs=='chaudiere fioul'

# %%
libs.value_counts()
# Out:
# ballon electrique                                            74718
# chaudiere mixte gaz                                          26181
# non affecte                                                  12879
# production mixte indeterminee                                11071
# ecs collective reseau de chaleur                              7959
# chaudiere fioul                                               7824
# chaudiere gaz                                                 5091
# ballon thermodynamique electrique                             4082
# chaudiere mixte indeterminee                                  3149
# chaudiere mixte bois                                          1776
# chauffe-eau gaz independant                                   1269
# pompe a chaleur combinee ecs/chauffage (pac air/eau)          1192
# ecs instantanee electrique                                     803
# chaudiere gpl                                                  755
# pompe a chaleur combinee ecs/chauffage (pac geothermique)      129
# pompe a chaleur combinee ecs/chauffage (indeterminee)           87
# pompe a chaleur combinee ecs/chauffage (pac air/air)            70
# chauffe-eau gpl independant                                     43
# pompe a chaleur combinee ecs/chauffage (pac eau/eau)            39
# chauffe-eau fioul independant                                   38
# chaudiere mixte fioul                                            3
# Name: valeur_renseignee, dtype: int64

# %%
vr_ecs.loc[test].head(100).to_dict()
# Out:
# {51: 'combine au systeme: chaudiere fioul collective installee apres 2000 avec programmateur  emetteurs: radiateurs fonte<br/>',
#  158: 'chaudiere fioul installee entre 1981 et 1990<br/>becs : 2004, rd : 1, rg : 0.7, pn : 21, iecs : 1.7, fecs : 0',
#  261: 'chaudiere fioul installee apres 1991<br/>becs : 2221, rd : 1, rg : 0.8, pn : 21, iecs : 1.61, fecs : 0',
#  567: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur<br/>becs : 1985, rd : 1, rg : 0,8, pn : 18, iecs : 2,16, fecs : 0, vs : 130',
#  860: 'chaudiere fioul installee apres 1991<br/>becs : 2224, rd : 1, rg : 0,8, pn : 21, iecs : 1,43, fecs : 0',
#  940: 'chaudiere fioul basse temperature<br/>becs : 2044, rd : 1, rg : 0,8, pn : 21, iecs : 1,41, fecs : 0',
#  955: 'ecs 1 : production par chaudiere gaz, fioul, bois (0l)',
#  1072: 'combine au systeme: chaudiere fioul condensation<br/>becs : 1915, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  1107: 'ecs 1 : production par chaudiere gaz, fioul, bois (150l)',
#  1237: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  2324: "chaudiere fioul installee apres 1991, reseau d'eau isole<br/>becs : 2066, rd : 1, rg : 0.8, pn : 21, iecs : 1.62, fecs : 0",
#  2631: "chaudiere fioul installee apres 1991, reseau d'eau isole<br/>becs : 1587, rd : 1, rg : 0.7, pn : 21, iecs : 1.68, fecs : 0",
#  2763: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 2164, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  2961: "combine au systeme: chaudiere fioul installee apres 1991 regulee, avec thermostat d'ambiance, systeme basse temperature  <br/>becs : 2269, rd : 1, rg : 0,7, pn : 24, iecs : 1,45, fecs : 0",
#  3038: "combine au systeme: chaudiere fioul installee apres 1991 avec programmateur, reseau d'eau isole  <br/>becs : 1546, rd : 1, rg : 0,7, pn : 24, iecs : 1,73, fecs : 0",
#  3055: "chaudiere standard, mixte :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - date de fabrication : 01/01/2000\r\\n - puissance nominale : 24 kw\r\\n - rendement a pleine charge : 86.76 %\r\\n - perte a l'arret : 0.24 kw\r\\n - detail de l'installation :\r\\n   - production hors volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation collective\r\\n   - reseau collectif non isole\r\\n",
#  3426: "combine au systeme: chaudiere fioul basse temperature reseau d'eau isole  emetteurs: radiateurs, reseau d'eau isole<br/>becs : 1838, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0, vs : 7",
#  3549: 'chaudiere fioul installee apres 1991<br/>becs : 1750, rd : 1, rg : 0,7, pn : 21, iecs : 1,66, fecs : 0',
#  3612: 'combine au systeme: chaudiere fioul basse temperature regulee, avec programmateur, systeme basse temperature<br/>becs : 2037, rd : 1, rg : 0,8, pn : 24, iecs : 1,61, fecs : 0',
#  4519: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur  <br/>becs : 1299, rd : 1, rg : 0,7, pn : 24, iecs : 3, fecs : 0, vs : 200',
#  4677: 'chaudiere fioul installee apres 1991<br/>becs : 1637, rd : 1, rg : 0,8, pn : 3, iecs : 2,02, fecs : 0, vs : 105',
#  5290: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1935, rd : 1, rg : 0,8, pn : 18, iecs : 2,06, fecs : 0, vs : 120',
#  6217: 'combine au systeme: chaudiere fioul installee entre 1976 et 1980 avec programmateur<br/>becs : 1961, rd : 1, rg : 0,6, pn : 18, iecs : 1,96, fecs : 0, vs : 25',
#  6412: 'combine au systeme: chaudiere fioul installee entre 1981 et 1990  <br/>becs : 2526, rd : 1, rg : 0.7, pn : 24, iecs : 1.49, fecs : 0',
#  6538: "ecs n°1 \\n type d'installation : sans ecs solaire \\n energie : fioul \\n type equipement : chaudiere fioul \\n contiguite des pieces : pieces contigues \\n position de la production : en volume chauffe \\n isolation du reseau : reseau non isole \\n volume de stockage : 150 \\n veilleuse : non \\n alimentation : heure pleine \\n ",
#  6706: 'combine au systeme: chaudiere fioul installee entre 1981 et 1990  emetteurs: radiateurs fonte  munis de robinets thermostatiques<br/>becs : 2130, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  7381: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur  <br/>becs : 1637, rd : 1, rg : 0,7, pn : 24, iecs : 1,71, fecs : 0',
#  7836: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  8388: "combine au systeme: chaudiere fioul installee apres 1991 avec programmateur, reseau d'eau isole  <br/>becs : 1568, rd : 1, rg : 0,7, pn : 24, iecs : 1,73, fecs : 0",
#  8890: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur  <br/>becs : 1646, rd : 1, rg : 0,7, pn : 24, iecs : 1,71, fecs : 0',
#  8924: 'ecs 1 : production par chaudiere gaz, fioul, bois (0l)',
#  8939: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  8960: "chaudiere basse temperature :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - puissance nominale : 0 kw\r\\n - rendement a pleine charge : 0 %\r\\n - perte a l'arret : 0 kw\r\\n - detail de l'installation :\r\\n   - presence d'un ballon d'accumulation de 100 litres de volume de stockage\r\\n   - production hors volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation collective\r\\n   - reseau collectif non isole\r\\n",
#  9321: "combine au systeme: chaudiere fioul installee apres 1991 avec thermostat d'ambiance  <br/>becs : 1652, rd : 1, rg : 0,7, pn : 24, iecs : 1,52, fecs : 0",
#  9786: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  10464: 'combine au systeme: chaudiere fioul <br/>becs : 1967, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  10603: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1860, rd : 1, rg : 0.7, pn : 24, iecs : 1.49, fecs : 0',
#  11216: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  11298: "ecs n°1 \\n type d'installation : sans ecs solaire \\n energie : fioul \\n type equipement : chaudiere fioul \\n contiguite des pieces : pieces contigues \\n position de la production : en volume chauffe \\n isolation du reseau : reseau non isole \\n volume de stockage : 200 \\n veilleuse : non \\n alimentation : heure pleine \\n ",
#  11426: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  11476: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  11736: "installation 1 : \\nsurface concernee : 81,8m²\\nelectricite, chauffe-eau, standard, type d'installation : individuelle, volume de stockage : 200 l, production : accumulation; ballon : vertical.\\n\\nfioul, chaudiere, basse temperature, type d'installation : individuelle, combinee, volume de stockage : 100 l, production : accumulation.",
#  11817: 'chaudiere fioul installee avant 1970 , couple avec un systeme solaire<br/>becs : 2033, rd : 1, rg : 0.7, pn : 2, iecs : 2.26, fecs : 54, vs : 200',
#  11988: "combine au systeme: chaudiere fioul installee apres 1991 regulee, reseau d'eau isole<br/>becs : 2211, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0",
#  12563: 'ecs 1 : production par chaudiere gaz, fioul, bois (50l)',
#  12607: 'chaudiere fioul installee entre 1970 et 1975<br/>becs : 1948, rd : 1, rg : 0.6, pn : 21, iecs : 2.21, fecs : 0',
#  13275: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1223, rd : 1, rg : 0,7, pn : 18, iecs : 1,59, fecs : 0',
#  13427: 'combine au systeme: chaudiere fioul installee apres 1991<br/>becs : 1941, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  13825: "installation 1 : \\nsurface concernee : 94,67m²\\nfioul, chaudiere, standard, type d'installation : individuelle, combinee, volume de stockage : 100 l, production : accumulation.",
#  14184: 'combine au systeme: chaudiere fioul installee apres 1991<br/>',
#  14564: 'combine au systeme: chaudiere fioul installee apres 1991<br/>',
#  15519: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  15882: "installation 1 : \\nsurface concernee : 127,95m²\\nfioul, chaudiere, basse temperature, type d'installation : collective, combinee, volume de stockage : 120 l, production : accumulation, puissance nominale : 28kw.\\ndistribution avec portion de reseau en volume non chauffe non ou mal isole\\n",
#  15888: "type d'equipement : chaudiere fioul\\nenergie : fioul\\ntype d'installation : individuelle, sans solaire\\ndescription : standard, anciennete 1998, mixte, sur sol, pn = 1.856 kwh\\ndistribution : production hors volume chauffe, pieces alimentees contigues\\nstockage : 200 l, vertical, hors volume chauffe\\n : \\n",
#  16092: "chaudiere classique :\r\\n - type de production : individuel\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - date de fabrication : 16/06/1972\r\\n - puissance nominale : 24 kw\r\\n - rendement a pleine charge : 79,76 %\r\\n - perte a l'arret : 0,72 kw\r\\n - detail de l'installation :\r\\n   - production hors volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation individuelle\r\\n",
#  16161: 'ecs 1 : production d ecs seule par chaudiere gaz, fioul ou chauffe-eau gaz (50l)',
#  16269: 'combine au systeme: chaudiere fioul basse temperature<br/>becs : 1888, rd : 1, rg : 0.7, pn : 24, iecs : 1.45, fecs : 0',
#  16697: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 2375, rd : 1, rg : 0,8, pn : 24, iecs : 1,44, fecs : 0',
#  16900: "chaudiere standard, mixte :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - date de fabrication : 13/06/1995\r\\n - puissance nominale : 18 kw\r\\n - rendement a pleine charge : 86,51 %\r\\n - perte a l'arret : 0,18 kw\r\\n - detail de l'installation :\r\\n   - production hors volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation individuelle\r\\n   - reseau collectif non isole\r\\n",
#  16970: 'chaudiere fioul installee apres 1991<br/>becs : 1828, rd : 1, rg : 0,7, pn : 21, iecs : 1,65, fecs : 0',
#  17081: "installation 1 : \\nsurface concernee : 77,65m²\\nfioul, chaudiere, standard, type d'installation : individuelle, production : accumulation.",
#  17123: 'combine au systeme: chaudiere fioul basse temperature  <br/>becs : 1502, rd : 1, rg : 0.7, pn : 24, iecs : 1.51, fecs : 0',
#  17203: 'combine au systeme: chaudiere fioul condensation<br/>becs : 2510, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  18765: 'combine au systeme: chaudiere fioul installee apres 1991<br/>becs : 2473, rd : 1, rg : 0,8, pn : 24, iecs : 1,43, fecs : 0',
#  18976: "chauffe-eau horizontal :\r\\n - type d'energie : electrique\r\\n - type de combustible : electricite\r\\n - detail de l'installation :\r\\n   - presence d'un ballon d'accumulation de 150 litres de volume de stockage\r\\n   - production en volume habitable\r\\n   - pieces alimentees contigues\r\\n   - installation individuelle\r\\n\r\\nchaudiere standard, mixte :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - puissance nominale : 0 kw\r\\n - rendement a pleine charge : 0 %\r\\n - perte a l'arret : 0 kw\r\\n - detail de l'installation :\r\\n   - production hors volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation collective\r\\n   - reseau collectif non isole\r\\n",
#  19403: "installation 1 : \\nsurface concernee : 104m²\\nfioul, chaudiere, standard, type d'installation : individuelle, combinee, volume de stockage : 100 l, production : accumulation.",
#  20385: "ecs n°1 \\n type d'installation : sans ecs solaire \\n energie : fioul \\n type equipement : chaudiere fioul \\n contiguite des pieces : pieces contigues \\n position de la production : en volume chauffe \\n isolation du reseau : reseau non isole \\n volume de stockage : 100 \\n veilleuse : non \\n alimentation : heure pleine \\n ",
#  21582: 'ecs 1 : production par chaudiere gaz, fioul, bois (100l)',
#  21633: 'combine au systeme: chaudiere fioul avec programmateur<br/>becs : 2277, rd : 1, rg : 0,7, pn : 24, iecs : 1,63, fecs : 0',
#  21794: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1904, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  22200: 'combine au systeme: chaudiere fioul apres 2000  avec programmateur<br/>becs : 2027, rd : 1, rg : 0,8, pn : 24, iecs : 1,43, fecs : 0',
#  22685: "installation 1 : \\nsurface concernee : 190m²\\nfioul, chaudiere, condensation, type d'installation : individuelle, combinee, volume de stockage : 120 l, production : accumulation.",
#  22834: 'ecs 1 : production par chaudiere gaz, fioul, bois (100l)',
#  22849: 'ecs 1 : production par chaudiere gaz, fioul, bois (100l)',
#  23205: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 2130, rd : 1, rg : 0,7, pn : 24, iecs : 1,64, fecs : 0',
#  23331: 'combine au systeme: chaudieres collective fioul guillot ld581 2004 et 2007<br/>',
#  23815: 'combine au systeme: chaudiere fioul basse temperature avec programmateur  <br/>becs : 1928, rd : 1, rg : 0,8, pn : 18, iecs : 2, fecs : 0, vs : 120',
#  24008: 'combine au systeme: chaudiere fioul installee entre 1976 et 1980  <br/>becs : 1777, rd : 1, rg : 0,6, pn : 24, iecs : 1,96, fecs : 0',
#  24424: 'chaudiere fioul installee entre 1976 et 1980<br/>becs : 1867, rd : 1, rg : 0,7, pn : 4, iecs : 1,81, fecs : 0, vs : 50',
#  24862: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur<br/>becs : 1980, rd : 1, rg : 0,7, pn : 24, iecs : 1,66, fecs : 0',
#  25766: "combine au systeme: chaudiere fioul installee apres 1991 avec thermostat d'ambiance  <br/>becs : 873, rd : 1, rg : 0,6, pn : 24, iecs : 1,77, fecs : 0",
#  26366: "chaudiere basse temperature :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - date de fabrication : 27/06/1997\r\\n - puissance nominale : 0 kw\r\\n - rendement a pleine charge : 0 %\r\\n - perte a l'arret : 0 kw\r\\n - detail de l'installation :\r\\n   - production hors volume habitable\r\\n   - pieces alimentees contigues\r\\n   - installation individuelle\r\\n   - reseau collectif non isole\r\\n",
#  26509: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 2164, rd : 1, rg : 0,7, pn : 24, iecs : 1,46, fecs : 0',
#  26731: "combine au systeme: chaudiere fioul installee apres 1991 reseau d'eau isole  , reseau d'eau isole, couple avec un systeme solaire<br/>becs : 2431, rd : 1, rg : 0.7, pn : 32, iecs : 2.25, fecs : 92, vs : 300",
#  26950: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 929, rd : 1, rg : 0.6, pn : 24, iecs : 1.95, fecs : 0',
#  26968: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  26994: 'combine au systeme: chaudiere fioul installee apres 1991 avec programmateur  <br/>becs : 1985, rd : 1, rg : 0.7, pn : 24, iecs : 1.48, fecs : 0',
#  27066: "installation 1 : \\nsurface concernee : 49,8m²\\nfioul, chaudiere, standard, type d'installation : collective, combinee, volume de stockage : 130 l, production : accumulation, puissance nominale : 21kw.\\ndistribution avec portion de reseau en volume non chauffe isole\\n\\ninstallation 2 : \\nsurface concernee : 49,8m²\\nelectricite, chauffe-eau, standard, type d'installation : individuelle, volume de stockage : 100 l, production : accumulation; ballon : vertical.",
#  27678: "chaudiere standard, mixte :\r\\n - type d'energie : fioul\r\\n - type de combustible : petrole brut, gazole, fioul domestique\r\\n - date de fabrication : 30/06/2004\r\\n - puissance nominale : 0 kw\r\\n - rendement a pleine charge : 0 %\r\\n - perte a l'arret : 0 kw\r\\n - detail de l'installation :\r\\n   - presence d'un ballon d'accumulation de 130 litres de volume de stockage\r\\n   - production en volume habitable\r\\n   - pieces alimentees non contigues\r\\n   - installation individuelle\r\\n   - reseau collectif non isole\r\\n",
#  27766: 'combine au systeme: chaudiere fioul installee entre 1981 et 1990  <br/>becs : 1790, rd : 1, rg : 0.7, pn : 24, iecs : 1.56, fecs : 0',
#  28412: 'combine au systeme: chaudiere fioul basse temperature avec programmateur  <br/>becs : 2188, rd : 1, rg : 0.8, pn : 24, iecs : 1.59, fecs : 0',
#  28690: 'ecs 1 : production par chaudiere gaz, fioul, bois (l)',
#  29257: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1784, rd : 1, rg : 0.7, pn : 24, iecs : 1.69, fecs : 0',
#  29542: 'combine au systeme: chaudiere fioul installee apres 1991  <br/>becs : 1477, rd : 1, rg : 0, pn : 0, iecs : 0, fecs : 0',
#  29612: 'ecs 1 : production par chaudiere gaz, fioul, bois (100l)',
#  29992: "ecs n°1 \\n type d'installation : sans ecs solaire \\n energie : fioul \\n type equipement : chaudiere fioul \\n contiguite des pieces : pieces contigues \\n position de la production : en volume chauffe \\n isolation du reseau : reseau non isole \\n volume de stockage : 150 \\n veilleuse : non \\n alimentation : heure pleine \\n ",
#  30027: "installation d'ecs 148\xa0m²\r\\n- ecs 1 : chaudiere mixte (chauffage + ecs) (energie : fioul) avec accumulation 150\xa0l ; production hors volume habitable",
#  30155: 'ecs 1 : production par chaudiere gaz, fioul, bois (145l)',
#  31081: "combine au systeme: chaudiere fioul condensation avec thermostat d'ambiance, reseau d'eau isole  <br/>becs : 2074, rd : 1, rg : 0,8, pn : 24, iecs : 2,14, fecs : 0, vs : 250",
#  31387: 'combine au systeme: chaudiere fioul installee entre 1981 et 1990  <br/>becs : 1800, rd : 1, rg : 0.7, pn : 24, iecs : 2.48, fecs : 0, vs : 150'}

# %%
table = td014

# %%
is_chaudiere = table.rpn>0


gen_ecs_concat_txt_desc = table["tv027_Type d'installation"].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc.loc[is_chaudiere] += 'chaudiere '

gen_ecs_concat_txt_desc += table['tv027_Type de système'].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table["tv032_Type de Générateur"].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table['tv036_Type de génération'].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table['tv037_Type de Production'].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table['tv040_Type de générateur'].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table["tv040_Type d'installation"].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table["tr004_description"].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table["tv045_Energie"].astype('string').replace(np.nan, '') + ' '
gen_ecs_concat_txt_desc += table['tv047_Type de Générateur'].astype('string').replace(np.nan, '') + ' '

# %%
gen_ecs_normalized_lib_matching_dict = {
    "ECS thermodynamique electrique(PAC ou ballon)": [('pompe a chaleur','pac','thermodynamique', 'air extrait','air exterieur'),
                                          ('electricite', 'electrique')],
    "ballon a accumulation electrique": [('ballon','classique','accumulation'),('electricite', 'electrique')],
    "ecs electrique indeterminee": [('electricite', 'electrique')],
    "ecs instantanee electrique": ['instantanee', ('electricite', 'electrique')],

    'chaudiere mixte gaz': ["chaudiere", 'mixte', ("gaz", "gpl")],
    'chaudiere mixte fioul': ["chaudiere", "mixte", "fioul"],
    'chaudiere mixte bois': [("bois", "biomasse")],

    'chauffe-eau gaz independant': [("individuelle ballon", "chauffe-eau", "accumulateur", "chauffe bain"), "gaz"],
    'chauffe-eau gpl independant': [("individuelle ballon", "chauffe-eau", "accumulateur", "chauffe bain"), "gpl"],

    'chauffe-eau fioul independant': [("individuelle ballon", "chauffe-eau", "accumulateur", "chauffe bain"), "fioul"],
    "ecs collective reseau chaleur": ["reseau", "chaleur"],

    'chaudiere gaz': ["chaudiere", "gaz"],
    'chaudiere gpl': ["chaudiere", "gpl"],

    'chaudiere fioul': ["chaudiere", "fioul"],

}

# %%
from utils import clean_str,strip_accents,affect_lib_by_matching_score

# %%
gen_ecs_concat_txt_desc = gen_ecs_concat_txt_desc.str.lower().apply(lambda x: strip_accents(x))

table['gen_ecs_concat_txt_desc'] = gen_ecs_concat_txt_desc

table['gen_ecs_concat_txt_desc'] = table['gen_ecs_concat_txt_desc'].apply(lambda x: clean_str(x))

# calcul gen_ecs_lib_infer par matching score text.
unique_gen_ecs = table.gen_ecs_concat_txt_desc.unique()
gen_ecs_lib_infer_dict = {k: affect_lib_by_matching_score(k, gen_ecs_normalized_lib_matching_dict) for k in
                         unique_gen_ecs}
table['gen_ecs_lib_infer'] = table.gen_ecs_concat_txt_desc.replace(gen_ecs_lib_infer_dict)
is_pac = table.coefficient_performance>2
table.loc[is_pac,'gen_ecs_lib_infer']="ECS thermodynamique electrique(PAC ou ballon)"

# %%
td006.columns
# Out:
# Index(['td006_batiment_id', 'td001_dpe_id', 'besoin_chauffage',
#        'deperdition_enveloppe', 'deperdition_renouvellement_air',
#        'tv014_permeabilite_id',
#        'tv015_valeur_conventionnelle_renouvellement_air_id',
#        'tv026_classe_inertie_id', 'altitude', 'nombre_niveau', 'hsp_moyenne',
#        'nombre_appartements', 'cclim', 'comclim'],
#       dtype='object')

# %%
mult_inst=table.groupby('td001_dpe_id').td013_installation_ecs_id.count()==2

# %%
dpe_mult=mult_inst[mult_inst].index

# %%
table.loc[table.td001_dpe_id.isin(dpe_mult)]
# Out:
#        td014_generateur_ecs_id td013_installation_ecs_id  \
# 194                      11894                     11492
# 195                      11895                     11492
# 277                      15398                     14878
# 278                      15399                     14878
# 379                      19912                     19245
# ...                        ...                       ...
# 109468                 6106411                   5400107
# 109469                 6106420                   5400116
# 109470                 6106421                   5400117
# 109498                 6107726                   5401389
# 109499                 6107727                   5401390
#
#        tr004_type_energie_id tv045_conversion_kwh_co2_id  \
# 194                TR004_004                   TV045_011
# 195                TR004_002                   TV045_016
# 277                TR004_004                   TV045_011
# 278                TR004_002                   TV045_016
# 379                TR004_004                   TV045_011
# ...                      ...                         ...
# 109468             TR004_002                   TV045_008
# 109469             TR004_002                   TV045_008
# 109470             TR004_002                   TV045_008
# 109498             TR004_002                   TV045_016
# 109499             TR004_002                   TV045_016
#
#        tv046_evaluation_contenu_co2_reseaux_id  coefficient_performance  \
# 194                                        NaN                      0.0
# 195                                        NaN                      0.0
# 277                                        NaN                      0.0
# 278                                        NaN                      0.0
# 379                                        NaN                      0.0
# ...                                        ...                      ...
# 109468                                     NaN                      3.0
# 109469                                     NaN                      2.1
# 109470                                     NaN                      3.0
# 109498                                     NaN                      0.0
# 109499                                     NaN                      0.0
#
#        tv032_coefficient_performance_id    rpn   qp0  puissance_veilleuse  \
# 194                                 NaN   0.87  0.24                  0.0
# 195                                 NaN   0.00  0.00                  0.0
# 277                                 NaN   0.00  0.00                  0.0
# 278                                 NaN   0.00  0.00                  0.0
# 379                                 NaN  89.38  0.18                  0.0
# ...                                 ...    ...   ...                  ...
# 109468                        TV032_001   0.00  0.00                  0.0
# 109469                        TV032_006   0.00  0.00                  0.0
# 109470                        TV032_001   0.00  0.00                  0.0
# 109498                              NaN   0.00  0.00                  0.0
# 109499                              NaN   0.00  0.00                  0.0
#
#         ... tv019_Type d'installation tv019_Ancienneté de l'installation  \
# 194     ...                       NaN                                NaN
# 195     ...                       NaN                                NaN
# 277     ...                       NaN                                NaN
# 278     ...                       NaN                                NaN
# 379     ...                       NaN                                NaN
# ...     ...                       ...                                ...
# 109468  ...                       NaN                                NaN
# 109469  ...                       NaN                                NaN
# 109470  ...                       NaN                                NaN
# 109498  ...                       NaN                                NaN
# 109499  ...                       NaN                                NaN
#
#         tv019_Fecs tv027_Type d'installation tv027_Type de Production  \
# 194            NaN                       NaN                      NaN
# 195            NaN                       NaN                      NaN
# 277            NaN                       NaN                      NaN
# 278            NaN                       NaN                      NaN
# 379            NaN                Collective   Toutes les productions
# ...            ...                       ...                      ...
# 109468         NaN              Individuelle           A accumulation
# 109469         NaN              Individuelle           A accumulation
# 109470         NaN              Individuelle           A accumulation
# 109498         NaN                       NaN                      NaN
# 109499         NaN                       NaN                      NaN
#
#              tv027_Type de système  tv027_Zone Hivers tv027_Prs2  \
# 194                            NaN                NaN        NaN
# 195                            NaN                NaN        NaN
# 277                            NaN                NaN        NaN
# 278                            NaN                NaN        NaN
# 379              Tous les systèmes                 H1       1.05
# ...                            ...                ...        ...
# 109468  Ballon en volume habitable                 H1       3.70
# 109469  Ballon en volume habitable                 H1       3.70
# 109470  Ballon en volume habitable                 H1       3.70
# 109498                         NaN                NaN        NaN
# 109499                         NaN                NaN        NaN
#
#                                   gen_ecs_concat_txt_desc  \
# 194            chaudiere autres energies fioul domestique
# 195     electricite electricite (hors electricite d'or...
# 277                      autres energies fioul domestique
# 278     electricite electricite (hors electricite d'or...
# 379     collective chaudiere tous les systemes basse t...
# ...                                                   ...
# 109468  individuelle ballon en volume habitable pac ai...
# 109469  individuelle ballon en volume habitable chauff...
# 109470  individuelle ballon en volume habitable pac ai...
# 109498  accumulation electrique classique individuelle...
# 109499  semi-accumulation electrique classique individ...
#
#                                     gen_ecs_lib_infer
# 194                                   chaudiere fioul
# 195                       ecs electrique indeterminee
# 277                                       non affecte
# 278                       ecs electrique indeterminee
# 379                                   chaudiere fioul
# ...                                               ...
# 109468  ECS thermodynamique electrique(PAC ou ballon)
# 109469  ECS thermodynamique electrique(PAC ou ballon)
# 109470  ECS thermodynamique electrique(PAC ou ballon)
# 109498               ballon a accumulation electrique
# 109499               ballon a accumulation electrique
#
# [2898 rows x 84 columns]

# %%
table['gen_ecs_lib_infer'].value_counts().to_dict()
# Out:
# {'ecs electrique indeterminee': 43418,
#  'chaudiere gaz': 25580,
#  'ballon a accumulation electrique': 16628,
#  'chaudiere mixte gaz': 7434,
#  'ECS thermodynamique electrique(PAC ou ballon)': 5013,
#  'non affecte': 4954,
#  'chaudiere fioul': 3218,
#  'chaudiere mixte fioul': 1380,
#  'chaudiere mixte bois': 1033,
#  'ecs collective reseau chaleur': 719,
#  'ecs instantanee electrique': 67,
#  'chauffe-eau gaz independant': 58,
#  'chauffe-eau fioul independant': 4}

# %%
{'ecs electrique indeterminee': 'ecs à effet joule electrique',
 'chaudiere gaz': 'chaudiere gaz',
 'ballon a accumulation electrique': 'ecs à effet joule electrique',
 'chaudiere mixte gaz': 'chaudiere gaz',
 'ECS thermodynamique electrique(PAC ou ballon)': 5013,
 'non affecte': 4954,
 'chaudiere fioul': 3218,
 'chaudiere mixte fioul': 1380,
 'chaudiere mixte bois': 1033,
 'ecs collective reseau chaleur': 719,
 'ecs instantanee electrique': 67,
 'chauffe-eau gaz independant': 58,
 'chauffe-eau fioul independant': 4}

# %%
test='non affecte'

# %%
(table.loc[table.gen_ecs_lib_infer==test]['rpn']>0).sum()
# Out:
# 1

# %%
table.loc[table.gen_ecs_lib_infer==test].gen_ecs_concat_txt_desc.value_counts()
# Out:
# autres energies                     3228
# autres energies fioul domestique    1724
# chaudiere autres energies              1
# autres energies charbon                1
# Name: gen_ecs_concat_txt_desc, dtype: int64

# %%
table.loc[is_elec].count().sort_values(ascending=False).to_dict()
# Out:
# {'gen_ecs_lib_infer': 62296,
#  'gen_ecs_concat_txt_desc': 62296,
#  'td013_installation_ecs_id': 62296,
#  'tr004_type_energie_id': 62296,
#  'tv045_conversion_kwh_co2_id': 62296,
#  'puissance_nominale': 62296,
#  'td001_dpe_id': 62296,
#  'tr004_description': 62296,
#  'tr004_est_efface': 62296,
#  'tr004_simulateur': 62296,
#  'td014_generateur_ecs_id': 62296,
#  'volume_stockage': 62288,
#  'tv045_Energie': 62245,
#  'tv045_Méthode': 62245,
#  'tv045_Type de production': 62245,
#  'tv045_Taux de conversion\nkg/kWh': 62245,
#  'coefficient_performance': 60811,
#  'puissance_veilleuse': 60811,
#  'qp0': 60811,
#  'rpn': 60811,
#  "tv040_Type d'installation": 18803,
#  'tv040_Type de générateur': 18803,
#  'tv048_rendement_stockage_ecs_id': 18803,
#  'tv040_rendement_distribution_ecs_id': 18803,
#  'tv040_Rd': 18803,
#  'tv048_Rs': 18803,
#  "tv048_Type d'accumulation": 18803,
#  'tv049_perte_stockage_ecs_id': 18788,
#  'tv049_Type de stockage': 18788,
#  'tv049_Qg,w': 18788,
#  'tv040_Production en volume habitable': 18177,
#  'tv043_pertes_stockage_id': 17779,
#  'tv043_Type de chauffe-eau': 17779,
#  'tv043_Cr': 17779,
#  'tv047_rendement_generation_ecs_id': 17438,
#  'tv047_Type de Générateur': 17438,
#  'tv047_Rg': 17438,
#  'tv043_Volume de stockage ECS': 16937,
#  'tv040_Pièces alimentées contiguës': 14296,
#  'tv027_Type de Production': 13056,
#  'tv027_pertes_recuperees_ecs_id': 13056,
#  "tv027_Type d'installation": 13056,
#  'tv027_Type de système': 13056,
#  'tv027_Zone Hivers': 13056,
#  'tv027_Prs2': 13056,
#  'tv037_puissance_necessaire_production_ecs_id': 5669,
#  'tv037_Type de Production': 5669,
#  'tv037_Pecs': 5669,
#  'tv037_Capacité Vs': 5669,
#  'tv032_coefficient_performance_id': 1683,
#  'tv041_coefficient_emplacement_fonctionnement_id': 1648,
#  'tv041_Alimentation': 1648,
#  'tv041_Ballon en volume habitable': 1648,
#  'tv041_Cef': 1648,
#  'tv032_COP': 1606,
#  'tv032_Type de Générateur': 1606,
#  'tv036_puissance_veilleuse_id': 195,
#  'tv036_Type de génération': 195,
#  'tv036_Ancienneté': 195,
#  'tv036_Type de Chaudière': 195,
#  'tv036_Veilleuse': 195,
#  'tv036_Qp0': 195,
#  'tv036_Rpint': 195,
#  'tv036_Rpn': 195,
#  "tv019_Type d'installation": 114,
#  'tv019_fecs_id': 114,
#  'tv019_Fecs': 114,
#  'tv019_Unnamed: 1': 114,
#  "tv019_Ancienneté de l'installation": 87,
#  'tv046_evaluation_contenu_co2_reseaux_id': 51,
#  'tv038_puissance_nominale_id': 31,
#  'tv038_Type de chaudière': 31,
#  "tv038_Type d'installation": 31,
#  "tv038_Année d'installation": 31,
#  'tv038_Pdim': 31,
#  'tv038_Pn': 31,
#  "tv046_Date d'effectivité": 0,
#  'tv046_Type de production': 0,
#  'tv036_Pn': 0,
#  'tv046_Localisation': 0,
#  'tv046_Nom du Réseau': 0,
#  'tv046_Département': 0,
#  'tr004_simu_ordre': 0,
#  'tv046_CO2': 0}
